# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\Khans\Downloads\Datasett.csv',low_memory=False)

# %%
df.head()
#this is how my data looks like . it is uncleaned having null values and unnamed columns
# Out:
#   Billings; Europe, Sectors & Countries  Unnamed: 1               Unnamed: 2  \
# 0       Source: Morgan Stanley Research         NaN                      NaN
# 1                                   NaN         NaN                      NaN
# 2                                     1         2.0                        9
# 3                                   NaN         NaN  Europe - On Trailing EY
# 4                                   NaN         NaN                   Market
#
#                                 Unnamed: 3                         Unnamed: 4  \
# 0                                      NaN                                NaN
# 1                                      NaN                                NaN
# 2                                       10                                 11
# 3  Consumer Discretionary - On Trailing EY  Consumer Staples - On Trailing EY
# 4                                  Sectors                                NaN
#
# ...

# %%
df.drop([0,1,2],inplace=True)
#dropping these three rows because it contains no values at any columns. so dropping it

# %%
df.head()
# Out:
#   Billings; Europe, Sectors & Countries  Unnamed: 1               Unnamed: 2  \
# 3                                   NaN         NaN  Europe - On Trailing EY
# 4                                   NaN         NaN                   Market
# 5                                   NaN         NaN                     EURO
# 6                             31-Dec-74         NaN                    27536
# 7                              1-Jan-75         NaN                      NaN
#
#                                 Unnamed: 3                         Unnamed: 4  \
# 3  Consumer Discretionary - On Trailing EY  Consumer Staples - On Trailing EY
# 4                                  Sectors                                NaN
# 5                                  EURO_25                            EURO_30
# 6                                    26861                            25887.8
# 7                                      NaN                                NaN
#
# ...

# %%
#df.reset_index(drop=True).head()

# %%
df.dropna(how='all',axis=1,inplace=True)
#dropping all null columns

# %%
df.loc[4] = df.loc[4].ffill()
#filling null values at given row by using forward fill method.

# %%
df.head()
# Out:
#   Billings; Europe, Sectors & Countries               Unnamed: 2  \
# 3                                   NaN  Europe - On Trailing EY
# 4                                   NaN                   Market
# 5                                   NaN                     EURO
# 6                             31-Dec-74                    27536
# 7                              1-Jan-75                      NaN
#
#                                 Unnamed: 3                         Unnamed: 4  \
# 3  Consumer Discretionary - On Trailing EY  Consumer Staples - On Trailing EY
# 4                                  Sectors                            Sectors
# 5                                  EURO_25                            EURO_30
# 6                                    26861                            25887.8
# 7                                      NaN                                NaN
#
#                 Unnamed: 5                   Unnamed: 6  \
# ...

# %%
df.reset_index(drop=True).head()
#resetting indexes.
# Out:
#   Billings; Europe, Sectors & Countries               Unnamed: 2  \
# 0                                   NaN  Europe - On Trailing EY
# 1                                   NaN                   Market
# 2                                   NaN                     EURO
# 3                             31-Dec-74                    27536
# 4                              1-Jan-75                      NaN
#
#                                 Unnamed: 3                         Unnamed: 4  \
# 0  Consumer Discretionary - On Trailing EY  Consumer Staples - On Trailing EY
# 1                                  Sectors                            Sectors
# 2                                  EURO_25                            EURO_30
# 3                                    26861                            25887.8
# 4                                      NaN                                NaN
#
#                 Unnamed: 5                   Unnamed: 6  \
# ...

# %%
df.iloc[2]
#accessing 2nd row of the dataframe
# Out:
# Billings; Europe, Sectors & Countries        NaN
# Unnamed: 2                                  EURO
# Unnamed: 3                               EURO_25
# Unnamed: 4                               EURO_30
# Unnamed: 5                               EURO_10
#                                           ...
# Unnamed: 256                                  PT
# Unnamed: 257                                  ES
# Unnamed: 258                                  SE
# Unnamed: 259                                  CH
# Unnamed: 260                                  GB
# Name: 5, Length: 256, dtype: object

# %%
df.iloc[2] = df.iloc[0]+" - "+df.iloc[1]+" - "+df.iloc[2]
df.head()
#concatnating 0,1 and 2nd row and sepratting them by using '-'.
# Out:
#   Billings; Europe, Sectors & Countries  \
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                             31-Dec-74
# 7                              1-Jan-75
#
#                                 Unnamed: 2  \
# 3                  Europe - On Trailing EY
# 4                                   Market
# 5  Europe - On Trailing EY - Market - EURO
# 6                                    27536
# 7                                      NaN
#
#                                           Unnamed: 3  \
# 3            Consumer Discretionary - On Trailing EY
# 4                                            Sectors
# 5  Consumer Discretionary - On Trailing EY - Sect...
# 6                                              26861
# 7                                                NaN
#
#                                           Unnamed: 4  \
# 3                  Consumer Staples - On Trailing EY
# ...

# %%
df.iloc[2]
#this is how 2nd row looks like after concatanating 2 other rows looks like
# Out:
# Billings; Europe, Sectors & Countries                                                  NaN
# Unnamed: 2                                         Europe - On Trailing EY - Market - EURO
# Unnamed: 3                               Consumer Discretionary - On Trailing EY - Sect...
# Unnamed: 4                               Consumer Staples - On Trailing EY - Sectors - ...
# Unnamed: 5                                     Energy - On Trailing EY - Sectors - EURO_10
#                                                                ...
# Unnamed: 256                                   Portugal - On Trailing BVY - Countries - PT
# Unnamed: 257                                      Spain - On Trailing BVY - Countries - ES
# Unnamed: 258                                     Sweden - On Trailing BVY - Countries - SE
# Unnamed: 259                                Switzerland - On Trailing BVY - Countries - CH
# Unnamed: 260                             United Kingdom - On Trailing BVY - Countries - GB
# ...

# %%
v=df.iloc[2]
#assigning 2nd row to a new variable called v

# %%
v[0]='date'
#giving name 'date' to the 0th element of v.

# %%
df.columns=v
#making  date columns out of v

# %%
df=df[3:]
#accesing elements from 3rd row to the end .

# %%
df=df.rename_axis(None,axis=1)

# %%
df.head()
# Out:
#          date Europe - On Trailing EY - Market - EURO  \
# 6   31-Dec-74                                   27536
# 7    1-Jan-75                                     NaN
# 8    2-Jan-75                                     NaN
# 9    3-Jan-75                                     NaN
# 10   6-Jan-75                                     NaN
#
#    Consumer Discretionary - On Trailing EY - Sectors - EURO_25  \
# 6                                               26861
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
#
#    Consumer Staples - On Trailing EY - Sectors - EURO_30  \
# 6                                             25887.8
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# ...

# %%
b = df.columns.tolist()[1:]
df=df.melt(id_vars=['date'],value_vars=b)
#df.melt() function unpivots a DataFrame from wide format to long format

# %%
df.head()
#structured unleaned data
# Out:
#         date                                 variable  value
# 0  31-Dec-74  Europe - On Trailing EY - Market - EURO  27536
# 1   1-Jan-75  Europe - On Trailing EY - Market - EURO    NaN
# 2   2-Jan-75  Europe - On Trailing EY - Market - EURO    NaN
# 3   3-Jan-75  Europe - On Trailing EY - Market - EURO    NaN
# 4   6-Jan-75  Europe - On Trailing EY - Market - EURO    NaN

# %%
b=df['variable'].str.split('-')

#splitting variable columns using split by '-'

# %%
b[0]
#accessing 0th element of b
# Out:
# ['Europe ', ' On Trailing EY ', ' Market ', ' EURO']

# %%
b[0][0]
# Out:
# 'Europe '

# %%
df[["segment","period","type","subtype"]] = df["variable"].str.split(" - ",expand=True)
df.drop("variable",axis=1,inplace=True)
df = df[["segment","period","subtype","value","date"]]
df
#spliting variable using by '-' and then assigning to into new columns
#adding date column and other newly created columns into data frame
# Out:
#                 segment           period subtype    value       date
# 0                Europe   On Trailing EY    EURO    27536  31-Dec-74
# 1                Europe   On Trailing EY    EURO      NaN   1-Jan-75
# 2                Europe   On Trailing EY    EURO      NaN   2-Jan-75
# 3                Europe   On Trailing EY    EURO      NaN   3-Jan-75
# 4                Europe   On Trailing EY    EURO      NaN   6-Jan-75
# ...                 ...              ...     ...      ...        ...
# 2839165  United Kingdom  On Trailing BVY      GB  29264.6  28-Aug-17
# 2839166  United Kingdom  On Trailing BVY      GB    28631  29-Aug-17
# 2839167  United Kingdom  On Trailing BVY      GB    28686  30-Aug-17
# 2839168  United Kingdom  On Trailing BVY      GB  28286.2  31-Aug-17
# 2839169  United Kingdom  On Trailing BVY      GB  29284.2   1-Sep-17
#
# [2839170 rows x 5 columns]

# %%
 
df.to_csv('cleaneddata.csv')
#saving cleaned data into csv format

# %%
df=pd.read_csv('cleaneddata.csv')

# %%
df1.drop('Unnamed: 0',axis=1)
# Out:
#                 segment           period subtype    value       date
# 0                Europe   On Trailing EY    EURO  27536.0  31-Dec-74
# 1                Europe   On Trailing EY    EURO      NaN   1-Jan-75
# 2                Europe   On Trailing EY    EURO      NaN   2-Jan-75
# 3                Europe   On Trailing EY    EURO      NaN   3-Jan-75
# 4                Europe   On Trailing EY    EURO      NaN   6-Jan-75
# ...                 ...              ...     ...      ...        ...
# 2839165  United Kingdom  On Trailing BVY      GB  29264.6  28-Aug-17
# 2839166  United Kingdom  On Trailing BVY      GB  28631.0  29-Aug-17
# 2839167  United Kingdom  On Trailing BVY      GB  28686.0  30-Aug-17
# 2839168  United Kingdom  On Trailing BVY      GB  28286.2  31-Aug-17
# 2839169  United Kingdom  On Trailing BVY      GB  29284.2   1-Sep-17
#
# [2839170 rows x 5 columns]

# %%
len(df['segment'].unique())
#how many  unique segments do we have in our data
# Out:
# 47

# %%
df['period'].value_counts()
#counting period values
# Out:
# On Trailing EY     567834
# On Forward EY      567834
# On Trailing DY     567834
# On Forward DY      567834
# On Trailing BVY    567834
# Name: period, dtype: int64

# %%
df['value']=df['value'].astype('float')
#converting dataype of value into float

# %%
#the sum of billings by segment
df.groupby(by='segment').value.sum().head(5)
# Out:
# segment
# Austria                     74103620.8
# Automobiles & Components    92306938.4
# Banks                       76493183.2
# Belgium                     87917478.2
# Capital Goods               76707012.0
# Name: value, dtype: float64

# %%
df.groupby('period').value.sum()
#sum of billing by period
# Out:
# period
# On Forward DY      6.597573e+08
# On Forward EY      4.561333e+08
# On Trailing BVY    1.200499e+09
# On Trailing DY     1.009537e+09
# On Trailing EY     9.957003e+08
# Name: value, dtype: float64

# %%
df.groupby('segment').value.describe().head(6)
#summary statistics by Segment
# Out:
#                                    count unique      top freq
# segment
# Austria                             5068   4861   7586.2    7
# Automobiles & Components            5130   4966  15504.2    3
# Banks                               5144   4998  11755.2    4
# Belgium                             5097   4937  10635.2    3
# Capital Goods                       5198   4992    20000    5
# Commercial & Professional Services  4820   4650   7516.4    3

# %%
#find the unique and there count for subtype
print(df['subtype'].unique())
print(df['subtype'].value_counts())
# Out:
# ['EURO' 'EURO_25' 'EURO_30' 'EURO_10' 'EURO_40' 'EURO_35' 'EURO_20'
#  'EURO_45' 'EURO_15' 'EURO_50' 'EURO_55' 'EURO_2510' 'EURO_4010'
#  'EURO_2010' 'EURO_2020' 'EURO_2520' 'EURO_2530' 'EURO_4020' 'EURO_1010'
#  'EURO_3010' 'EURO_3020' 'EURO_3510' 'EURO_3030' 'EURO_4030' 'EURO_1510'
#  'EURO_2540' 'EURO_3520' 'EURO_4040' 'EURO_2550' 'EURO_4530' 'EURO_4510'
#  'EURO_4520' 'EURO_5010' 'EURO_2030' 'EURO_5510' 'AT' 'BE' 'DK' 'FI' 'FR'
#  'DE' 'GR' 'IE' 'IT' 'NL' 'NO' 'PT' 'ES' 'SE' 'CH' 'GB']
# EURO         55670
# FI           55670
# EURO_2550    55670
# EURO_4530    55670
# EURO_4510    55670
# EURO_4520    55670
# EURO_5010    55670
# EURO_2030    55670
# EURO_5510    55670
# AT           55670
# BE           55670
# DK           55670
# FR           55670
# EURO_3520    55670
# DE           55670
# GR           55670
# IE           55670
# IT           55670
# NL           55670
# NO           55670
# PT           55670
# ES           55670
# SE           55670
# ...

# %%
#Count nan values in values columns and fill it with appropriate values
df['value'].isnull().sum()
# Out:
# 2598248

# %%
df['value'].describe()
# Out:
# count     240922
# unique    113168
# top        20000
# freq          97
# Name: value, dtype: object

# %%
#detecting outliers
import seaborn as sns
import matplotlib.pyplot as plt
#find out there are outliers in values columns
sns.boxplot(x=df['value'])
plt.show()
#in simple words outlier is nothing but these are value in our datset which lies away from the clustered data .
#box plot is the best way to detect outliers . it can help one to visually look for outlier in our data. below we can see that we have outliers.

# %%
from scipy import stats
import numpy as np

# %%
df['value'].quantile(0.25)
#25th percentile of the data
# Out:
# 11028.25

# %%
df['value'].quantile(0.75)
#75th percentile
# Out:
# 21633.8

# %%
Q1=df['value'].quantile(0.25)
Q3=df['value'].quantile(0.75)
IQR=Q3-Q1
#interquantile range, which is 75th percentile - 25th percentile

# %%
IQR
# Out:
# 10605.55

# %%
lower_lim=Q1-1.5*IQR
upper_lim=Q3+1.5*IQR
#lower limit or lower fence of the data
#upper limit or upper fence of the data

# %%
lower_lim
# Out:
# -4880.074999999999

# %%
upper_lim
# Out:
# 37542.125

# %%
#left_outlier=df['value']<lower_lim
#right_outlier=df['value']>upper_lim

# %%
outliers = []
for i in df['value']:
    if (i<lower_lim) or (i>upper_lim):
        outliers.append(i)
#detecting outlier in the dataset . we have set a condition that if value is lower than lower limit and if value is higher than upper limit we will treat it as outlier.

# %%
len(outliers)
#these are the outliers in our dataset
# Out:
# 8510

# %%
#count nan values in values columns and fill it with appropriate values
df['value'].isnull().count()
# Out:
# 2839170

# %%
df['value'].isnull().sum().sum()
# Out:
# 2598248

# %%
df['value'] = df['value'].fillna(df['value'].mean())
#filling null values by mean

# %%
df['value'].isnull().sum().sum()
# Out:
# 0

# %%
#apply descriptive stats on values column and describe the output 
df.value.describe()
# Out:
# count    2.839170e+06
# mean     1.793787e+04
# std      5.149951e+03
# min      6.668000e+02
# 25%      1.793787e+04
# 50%      1.793787e+04
# 75%      1.793787e+04
# max      1.427762e+06
# Name: value, dtype: float64
